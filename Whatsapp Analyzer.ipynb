# %% [markdown]
# ## Whatsapp chat analyzer

# %% [markdown]
# ### Import packages

# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
from nltk.corpus import stopwords
import warnings
warnings.filterwarnings('ignore')
import glob
import importlib
from importlib import reload as rl
# %matplotlib inline
import base_file as f

# Print all files in the folder 
# print(glob.glob("datafiles\*.txt"))

# Transform and load data
df = f.extract_msg(r"datafiles\fam_chat_1.txt", r"datafiles\fam_chat_2.txt")
# Out:
# ['datafiles\\Hoeschis.txt', 'datafiles\\Hoesch_mit_Allen.txt']

# %% [markdown]
# ### Descriptives

# %%
f.describe_msgs(df)
# Out:
# The first message was sent on:  2016-01-10 14:26:43
#
# The last message was sent 3.96 years later, on:  2019-12-27 10:37:49
#
# Number of messages sent 15250
#
# Members of this chat:  Mama, Papa, Tati, Lexi, Milla, Isa, Adschie, Omi Usa, Lolli, Josh, Omi Subach
#
# Most messages were sent by: Tati

# %% [markdown]
# ### Longest Monologue

# %%
f.monologue(df)
# Out:
# The longest monologue is from Lolli with 135 consecutive lines of messages

# %% [markdown]
# ### Messages sent per person

# %%
f.plot_msg_pp(df)

# %% [markdown]
# ### Most Gif/Media

# %%
f.plot_most_media(df)

# %% [markdown]
# ### Most haha

# %%
f.plot_most_haha(df)

# %% [markdown]
# ### Most YELLING/capitalized words

# %%
f.plot_most_YELLING(df)

# %% [markdown]
# ### Most common words

# %%
#wordcloud
f.plot_wordcloud(df, max_words=100)

# %% [markdown]
# ### Most emojis sent

# %%
f.plot_emojis(df)

# %% [markdown]
# ### missing: timeseries analysis

# %%
f.plot_msgs_over_time(df)
